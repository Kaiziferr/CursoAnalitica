# %%
import pandas as pd

# %%
df = pd.read_csv('Pandas-Tutorial/RegularSeasonCompactResults.csv')
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %%
df.tail()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145289 entries, 0 to 145288
# Data columns (total 8 columns):
# Season    145289 non-null int64
# Daynum    145289 non-null int64
# Wteam     145289 non-null int64
# Wscore    145289 non-null int64
# Lteam     145289 non-null int64
# Lscore    145289 non-null int64
# Wloc      145289 non-null object
# Numot     145289 non-null int64
# dtypes: int64(7), object(1)
# memory usage: 8.9+ MB

# %%
display(type(df['Season']), type(df[['Season']]))
# Out:
# pandas.core.series.Series
# pandas.core.frame.DataFrame

# %%
mask = (df['Season'] > 1985)
df[mask].head()
# Out:
#       Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 3737    1986      24   1181      66   1249      62    N      0
# 3738    1986      24   1412      71   1401      68    N      0
# 3739    1986      25   1133      94   1260      84    A      0
# 3740    1986      25   1197      88   1126      70    N      0
# 3741    1986      25   1208      78   1418      75    A      0

# %%
mask = (df[['Season']]>1985)
df[mask].head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0     NaN     NaN    NaN     NaN    NaN     NaN  NaN    NaN
# 1     NaN     NaN    NaN     NaN    NaN     NaN  NaN    NaN
# 2     NaN     NaN    NaN     NaN    NaN     NaN  NaN    NaN
# 3     NaN     NaN    NaN     NaN    NaN     NaN  NaN    NaN
# 4     NaN     NaN    NaN     NaN    NaN     NaN  NaN    NaN

# %%
df.loc[:,['Wscore','Numot']].head()
# Out:
#    Wscore  Numot
# 0      81      0
# 1      77      0
# 2      63      0
# 3      70      0
# 4      86      0

# %%
df.shape
# Out:
# (145289, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=145289, step=1)

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %%
display(df.max(), df.min())
# Out:
# Season    2016
# Daynum     132
# Wteam     1464
# Wscore     186
# Lteam     1464
# Lscore     150
# Wloc         N
# Numot        6
# dtype: object
# Season    1985
# Daynum       0
# Wteam     1101
# Wscore      34
# Lteam     1101
# Lscore      20
# Wloc         A
# Numot        0
# dtype: object

# %%
type(df.max())
# Out:
# pandas.core.series.Series

# %%
df['Wscore'].max()
# Out:
# 186

# %%
df['Lscore'].mean()
# Out:
# 64.49700940883343

# %%
df['Lscore'].std()
# Out:
# 11.380624668827176

# %%
df['Wscore'].argmax()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 24970

# %%
df['Wscore'].idxmax()
# Out:
# 24970

# %%
df['Wscore'].max()
# Out:
# 186

# %%
mask = df['Wscore']
mask[24970]
# Out:
# 186

# %%
a = mask >=186
df[a]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %%
df.iloc[[df['Wscore'].idxmax()]]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %%
df.iloc[[df['Wscore'].idxmax()]]["Lscore"]
# Out:
# 24970    140
# Name: Lscore, dtype: int64

# %%
df.iloc[[df['Wscore'].idxmax()]]["Lscore"][24970]
# Out:
# 140

# %%
df.iloc[0:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0

# %%
df.loc[:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0

# %%
df.loc[df['Wscore'].idxmax(), 'Lscore']
# Out:
# 140

# %%
df.sort_values('Wscore').tail()
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 20022    1990      40   1116     166   1109     101    H      0
# 24341    1991      47   1328     172   1258     112    H      0
# 19653    1990      30   1328     173   1109     101    H      0
# 17867    1989      92   1258     181   1109     150    H      0
# 24970    1991      68   1258     186   1109     140    H      0

# %%
a = df.groupby('Lscore')

# %%
df[a]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %%
df[df['Wscore']>150].head()
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 5269     1986      75   1258     151   1109     107    H      0
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 16040    1989      40   1328     152   1331     122    H      0
# 16853    1989      68   1258     162   1109     144    A      0

# %%
df[(df['Wscore']>150) & (df['Lscore']<100)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 25656    1991      84   1106     151   1212      97    H      0
# 28687    1992      54   1261     159   1319      86    H      0
# 35023    1993     112   1380     155   1341      91    A      0
# 52600    1998      33   1395     153   1410      87    H      0

# %%
df.groupby('Wteam')['Wscore'].mean().head()
# Out:
# Wteam
# 1101    78.111111
# 1102    69.893204
# 1103    75.839768
# 1104    75.825944
# 1105    74.960894
# Name: Wscore, dtype: float64

# %%
df.groupby('Wteam')['Wloc'].value_counts().head(9)
# Out:
# Wteam  Wloc
# 1101   H        12
#        A         3
#        N         3
# 1102   H       204
#        A        73
#        N        32
# 1103   H       324
#        A       153
#        N        41
# Name: Wloc, dtype: int64

# %%
df.values
# Out:
# array([[1985, 20, 1228, ..., 64, 'N', 0],
#        [1985, 25, 1106, ..., 70, 'H', 0],
#        [1985, 25, 1112, ..., 56, 'H', 0],
#        ...,
#        [2016, 132, 1246, ..., 77, 'N', 1],
#        [2016, 132, 1277, ..., 62, 'N', 0],
#        [2016, 132, 1386, ..., 74, 'N', 0]], dtype=object)

# %%
df[(df['Wteam']==1101)]
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 131950    2014      75   1101      73   1146      72    H      0
# 132860    2014      94   1101      87   1223      81    H      0
# 135619    2015      31   1101      72   1170      61    H      0
# 136263    2015      49   1101      65   1354      59    N      0
# 136343    2015      50   1101      69   1115      61    N      0
# 136740    2015      62   1101      87   1146      70    H      0
# 136953    2015      68   1101      71   1311      54    H      0
# 137131    2015      71   1101      95   1322      81    A      0
# 139440    2015     120   1101      83   1223      71    H      0
# 140642    2016      25   1101      72   1197      62    N      0
# 141972    2016      61   1101      62   1146      61    A      0
# 142481    2016      71   1101      87   1322      72    H      0
# 142816    2016      78   1101      75   1270      67    H      0
# ...

# %%
df.values
# Out:
# array([[1985, 20, 1228, ..., 64, 'N', 0],
#        [1985, 25, 1106, ..., 70, 'H', 0],
#        [1985, 25, 1112, ..., 56, 'H', 0],
#        ...,
#        [2016, 132, 1246, ..., 77, 'N', 1],
#        [2016, 132, 1277, ..., 62, 'N', 0],
#        [2016, 132, 1386, ..., 74, 'N', 0]], dtype=object)

# %%
df.values[0][0]
# Out:
# 1985

# %%
for index, row in df.iterrows():
    print(row)
    if index == 1:
        break
# Out:
# Season    1985
# Daynum      20
# Wteam     1228
# Wscore      81
# Lteam     1328
# Lscore      64
# Wloc         N
# Numot        0
# Name: 0, dtype: object
# Season    1985
# Daynum      25
# Wteam     1106
# Wscore      77
# Lteam     1354
# Lscore      70
# Wloc         H
# Numot        0
# Name: 1, dtype: object

# %%
df[['Wscore','Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %%
df.loc[:,['Wscore','Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %%
type(df['Wscore'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Wscore']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0

# %%
df.iloc[0:3,1]
# Out:
# 0    20
# 1    25
# 2    25
# Name: Daynum, dtype: int64

# %%
df.isnull().sum()
# Out:
# Season    0
# Daynum    0
# Wteam     0
# Wscore    0
# Lteam     0
# Lscore    0
# Wloc      0
# Numot     0
# dtype: int64
